# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with ' mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json
# 2025-04-10T22:45:08.712-0400	connected to: mongodb://localhost/
# 2025-04-10T22:45:08.713-0400	dropping: uk_food.establishments
# 2025-04-10T22:45:10.564-0400	39779 document(s) imported successfully. 0 document(s) failed to import.`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'artifacts', 'autosaurus', 'config', 'local', 'met', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(mongo.list_database_names())
# Out:
# ['admin', 'artifacts', 'autosaurus', 'config', 'local', 'met', 'uk_food']

# %%
# review the collections in our new database
db = mongo["uk_food"] #specify the database
collections = db.list_collection_names() #list collection names
print(collections) #print the collections
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
db = mongo["uk_food"]  # Select the database and collection
collection = db["establishments"]

# Get a single document from the collection
document = collection.find_one()

# Print the document
pprint(document)
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'CO': {'DAILY_AQI_VALUE': None},
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67f88234c4f6a8ddbd75efad'),
#  'geocode': {'latitude': Decimal128('51.0838120000000'),
# ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('67f9cb8ee3ca609a1c893709'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
results = establishments.find_one(new_restaurant)
pprint(results)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67f9cb8ee3ca609a1c893709'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType": "Restaurant/Cafe/Canteen"}
field = {'BusinessTypeID':1 , 'BusinessType':1, '_id': 0}
# Capture the results to a variable
results = establishments.find(query,field)

# Pretty print the first two results
for result in results:
    print(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
    {"BusinessName": "Penang Flavours"},
    {"$set": {"BusinessTypeID": 1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
updated_restaurant = establishments.find_one({"BusinessName": "Penang Flavours"})
pprint(updated_restaurant)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'CO': {'DAILY_AQI_VALUE': None},
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67f929ff41053349efeecc4a'),
#  'geocode': {'latitude': Decimal128('51.4901420000000'),
#              'longitude': Decimal128('0.0838400000000000')},
#  'latitude': None,
#  'longitude': None,
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count = establishments.count_documents({"LocalAuthorityName": "Dover"})
print(f"Documents containing Dover as LocalAuthorityName: {dover_count}")
# Out:
# Documents containing Dover as LocalAuthorityName: 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
delete_dover = establishments.delete_many({"LocalAuthorityName": "Dover"})
print(f"Deleted {delete_dover.deleted_count} documents.")
# Out:
# Deleted 0 documents.

# %%
# Check if any remaining documents include Dover
check_dover = establishments.count_documents({"LocalAuthorityName": "Dover"})
print(f"Remaining documents including Dover: {check_dover}")
# Out:
# Remaining documents including Dover: 0

# %%
# Check that other documents remain with 'find_one'
find_more = establishments.find_one()
print("Sample document after deletion:")
print(find_more)
# Out:
# Sample document after deletion:
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set': { "geocode.latitude" : {'$toDecimal': "$geocode.latitude"},
                                         "geocode.longitude" : {'$toDecimal': "$geocode.longitude"}
                                                                 }} ])
# Out:
# UpdateResult({'n': 38793, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set': { "RatingValue" : {'$toInt': "$RatingValue"}} } ])
# Out:
# UpdateResult({'n': 38793, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
# Query sample documents
query = {}
projection = {'geocode.longitude': 1, 'geocode.latitude': 1, 'RatingValue': 1, '_id': 0}
results = establishments.find(query, projection).limit(3)  # Check first 3 docs

# Analyze field types
for doc in results:
    print("Document:", doc)
    for field, value in doc.items():
        if isinstance(value, dict):  # Handle nested fields (e.g., geocode)
            for subfield, subvalue in value.items():
                print(f"  {field}.{subfield}:", type(subvalue))
        else:
            print(f"  {field}:", type(value))
    print("\n---\n")
# Out:
# Document: {'RatingValue': 5, 'geocode': {'longitude': Decimal128('1.19562500000000'), 'latitude': Decimal128('51.0838120000000')}}
#   RatingValue: <class 'int'>
#   geocode.longitude: <class 'bson.decimal128.Decimal128'>
#   geocode.latitude: <class 'bson.decimal128.Decimal128'>
#
# ---
#
# Document: {'RatingValue': 4, 'geocode': {'longitude': Decimal128('1.19640800000000'), 'latitude': Decimal128('51.0860580000000')}}
#   RatingValue: <class 'int'>
#   geocode.longitude: <class 'bson.decimal128.Decimal128'>
#   geocode.latitude: <class 'bson.decimal128.Decimal128'>
#
# ---
#
# Document: {'RatingValue': 5, 'geocode': {'longitude': Decimal128('1.19476200000000'), 'latitude': Decimal128('51.0857970000000')}}
#   RatingValue: <class 'int'>
#   geocode.longitude: <class 'bson.decimal128.Decimal128'>
#   geocode.latitude: <class 'bson.decimal128.Decimal128'>
#
# ---
